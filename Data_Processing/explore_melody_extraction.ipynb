# %% [markdown]
# # Explore extracting melody
# Since Fri. Nov. 12th, 2021
#
# Consider ways to extract melody from (valid) MiDi files, that sounds good enough
#
# Might need to consider allowing multiple pitches at a given time
#
#
# ## Setup

# %%
from icecream import ic

from util import *
from util import MidoUtil as Mu, PrettyMidiUtil as Pmu
from melody_extractor import MelodyExtractor

ic(eg_midis())
# Out:
# ic| eg_midis(): ['/Users/stefanh/Documents/UMich/Research/Music with '
#                  'NLP/datasets/MIDI-eg/AUD_DS1266.mid',
#                  '/Users/stefanh/Documents/UMich/Research/Music with NLP/datasets/MIDI-eg/Alan '
#                  'Walker - Faded (Carlo Prato).mid',
#                  '/Users/stefanh/Documents/UMich/Research/Music with '
#                  'NLP/datasets/MIDI-eg/Christina Perri - A Thousand Years (mididb).mid',
#                  '/Users/stefanh/Documents/UMich/Research/Music with NLP/datasets/MIDI-eg/Ed '
#                  'Sheeran - Shape of You (Carlo Prato).mid',
#                  '/Users/stefanh/Documents/UMich/Research/Music with NLP/datasets/MIDI-eg/Joe '
#                  'Hisaishi - Merry Go Round of Life (bitmidi).mid',
#                  '/Users/stefanh/Documents/UMich/Research/Music with '
#                  'NLP/datasets/MIDI-eg/Pharrell Williams - Get lucky ft..mid',
#                  '/Users/stefanh/Documents/UMich/Research/Music with '
#                  'NLP/datasets/MIDI-eg/Ryuichi Sakamoto - Merry Christmas Mr. Lawrence '
#                  '(freemidi).mid',
#                  '/Users/stefanh/Documents/UMich/Research/Music with '
#                  'NLP/datasets/MIDI-eg/Westlife - Seasons in the Sun.mid',
#                  '/Users/stefanh/Documents/UMich/Research/Music with '
#                  'NLP/datasets/MIDI-eg/bc8830293f19b2e3941ed0b2f8bd6f00.mid',
#                  '/Users/stefanh/Documents/UMich/Research/Music with '
#                  'NLP/datasets/MIDI-eg/chpn_op66.mid']
# ['/Users/stefanh/Documents/UMich/Research/Music with NLP/datasets/MIDI-eg/AUD_DS1266.mid',
#  '/Users/stefanh/Documents/UMich/Research/Music with NLP/datasets/MIDI-eg/Alan Walker - Faded (Carlo Prato).mid',
#  '/Users/stefanh/Documents/UMich/Research/Music with NLP/datasets/MIDI-eg/Christina Perri - A Thousand Years (mididb).mid',
#  '/Users/stefanh/Documents/UMich/Research/Music with NLP/datasets/MIDI-eg/Ed Sheeran - Shape of You (Carlo Prato).mid',
#  '/Users/stefanh/Documents/UMich/Research/Music with NLP/datasets/MIDI-eg/Joe Hisaishi - Merry Go Round of Life (bitmidi).mid',
#  '/Users/stefanh/Documents/UMich/Research/Music with NLP/datasets/MIDI-eg/Pharrell Williams - Get lucky ft..mid',
#  '/Users/stefanh/Documents/UMich/Research/Music with NLP/datasets/MIDI-eg/Ryuichi Sakamoto - Merry Christmas Mr. Lawrence (freemidi).mid',
#  '/Users/stefanh/Documents/UMich/Research/Music with NLP/datasets/MIDI-eg/Westlife - Seasons in the Sun.mid',
#  '/Users/stefanh/Documents/UMich/Research/Music with NLP/datasets/MIDI-eg/bc8830293f19b2e3941ed0b2f8bd6f00.mid',
#  '/Users/stefanh/Documents/UMich/Research/Music with NLP/datasets/MIDI-eg/chpn_op66.mid']

# %% [markdown]
# ## Get the bar with maximum average pitch
#
#
# ### Shape of You

# %%
fnm = eg_midis('Shape of You')
me = MelodyExtractor(fnm)

ic(me.fqs_ts, me.n_ts)
ic('seconds elapsed for a bar', me.n_ts / me.fqs_ts)
pr = me.pm.get_piano_roll(fs=me.fqs_ts)
ic(pr.shape)
Pmu.plot_piano_roll(me.pm, fqs=me.fqs_ts)
# Out:
# /usr/local/lib/python3.9/site-packages/pretty_midi/pretty_midi.py:97: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# ic| me.fqs_ts: 5.0, me.n_ts: 32.0
# ic| 'seconds elapsed for a bar', me.n_ts / me.fqs_ts: 6.4
# ic| pr.shape: (128, 370)
# /usr/local/lib/python3.9/site-packages/librosa/display.py:1335: UserWarning: Frequency axis exceeds Nyquist. Did you remember to set all spectrogram parameters in specshow?
#   warnings.warn(
# ic| plt.xticks(): (array([ 0., 10., 20., 30., 40., 50., 60., 70., 80.]),
#                    [Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, '')])
#     plt.yticks(): (array([   8.17579892,   16.35159783,   32.70319566,   65.40639133,
#                           130.81278265,  261.6255653 ,  523.2511306 , 1046.5022612 ,
#                          2093.0045224 , 4186.00904481]),
#                    [Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, '')])

# %% [markdown]
# ### Merry Go Round of Life

# %%
fnm = eg_midis('Merry Go Round of Life')

Pmu.plot_piano_roll(fnm, fqs=me.fqs_ts)

# me = MelodyExtractor(fnm)  # Assertion Error
# ic(me.fqs_ts, me.n_ts)
# ic('seconds elapsed for a bar', me.n_ts / me.fqs_ts)
# pr = me.pm.get_piano_roll(fs=me.fqs_ts)
# ic(pr.shape)
# Out:
# ic| plt.xticks(): (array([  0.,  50., 100., 150., 200., 250.]),
#                    [Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, '')])
#     plt.yticks(): (array([4.08789946e+00, 8.17579892e+00, 1.63515978e+01, 3.27031957e+01,
#                          6.54063913e+01, 1.30812783e+02, 2.61625565e+02, 5.23251131e+02,
#                          1.04650226e+03, 2.09300452e+03, 4.18600904e+03, 8.37201809e+03]),
#                    [Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, '')])

# %% [markdown]
# ### An example from LMD
# Looking at the music XML, pretty high-quality as, only 1 tempo and 1 time signature across the song

# %%
fnm = eg_midis('bc8830293f19b2e3941ed0b2f8bd6f00')
ic(Mu.get_tempo_changes(fnm))
Pmu.plot_piano_roll(fnm, fqs=me.fqs_ts)

# me = MelodyExtractor(fnm)  # Assertion Error
# ic(me.fqs_ts, me.n_ts)
# ic('seconds elapsed for a bar', me.n_ts / me.fqs_ts)
# pr = me.pm.get_piano_roll(fs=me.fqs_ts)
# ic(pr.shape)
# Out:
# ic| Mu.get_tempo_changes(fnm): [468750, 612244, 779220, 967741]
# ic| plt.xticks(): (array([  0.,  50., 100., 150., 200., 250., 300., 350.]),
#                    [Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, '')])
#     plt.yticks(): (array([   8.17579892,   16.35159783,   32.70319566,   65.40639133,
#                           130.81278265,  261.6255653 ,  523.2511306 , 1046.5022612 ,
#                          2093.0045224 , 4186.00904481]),
#                    [Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, ''),
#                     Text(0, 0, '')])
